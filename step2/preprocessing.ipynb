# %%
import pandas as pd

# %%
df_courses = pd.read_csv('../starter/Data/courses.csv')
df_courses.head()
# Out:
#   PartitionKey                                RowKey    source  \
# 0     ms-learn  273a7231-bbc2-4bb4-b6e1-fd46081f166d  MS Learn
# 1     ms-learn  4549ad74-9fbe-4924-8936-a033da90fb8f  MS Learn
# 2     ms-learn  23d8ac5b-0e98-4013-b001-7c8a3d69dca2  MS Learn
# 3     ms-learn  0f8e5c1d-9d71-4442-87f7-021140c90158  MS Learn
# 4     ms-learn  debf6a09-ab8c-4954-a8db-4ab5141b633c  MS Learn
#
#                                                title  \
# 0  Automate Node.js deployments with Azure Pipelines
# 1  Automate Node.js deployments with Azure Pipelines
# 2  Automate Node.js deployments with Azure Pipelines
# 3  Automate Node.js deployments with Azure Pipelines
# 4  Automate Node.js deployments with Azure Pipelines
#
#                                          description instructor     level  \
# 0  Implement CI/CD pipeline for Node.js applicati...        NaN  beginner
# 1  Implement CI/CD pipeline for Node.js applicati...        NaN  beginner
# ...

# %%
df_courses["duration"].unique()
# Out:
# array(['44', '82', '59', '54', '66', '28', '87', '40', '70', '22', '80',
#        '46', '62', '49', '65', '43', '56', '45', '30', '60', '16', '19',
#        '41', '72', '63', '36', '32', '69', '25', '77', '50', '37', '47',
#        '38', '74', '53', '104', '17', '18', '52', '35', '21', '42', '91',
#        '24', '68', '23', '73', '39', '29', '76', '64', '55', '34', '27',
#        '75', '51', '122', '108', '90', '12', '10', '61', '1', '3', '5',
#        '2', '3 months', '4 months ', '2 months ', '4 months', '3 Months',
#        '1 month', '2 months'], dtype=object)

# %%
df_courses['duration'] = df_courses['duration'].apply(lambda x: int(x.split()[0]) * 30 if 'month' in x.lower() else x)

# %%
df_courses["duration"].unique()
# Out:
# array(['44', '82', '59', '54', '66', '28', '87', '40', '70', '22', '80',
#        '46', '62', '49', '65', '43', '56', '45', '30', '60', '16', '19',
#        '41', '72', '63', '36', '32', '69', '25', '77', '50', '37', '47',
#        '38', '74', '53', '104', '17', '18', '52', '35', '21', '42', '91',
#        '24', '68', '23', '73', '39', '29', '76', '64', '55', '34', '27',
#        '75', '51', '122', '108', '90', '12', '10', '61', '1', '3', '5',
#        '2', 90, 120, 60, 30], dtype=object)

# %%
df_courses.tail(20)
# Out:
#        PartitionKey                                RowKey          source  \
# 975  company-moodle  c014cf36-2a83-4ded-bfe5-d62f405ba970  Company Moodle
# 976  company-moodle  6b5d3f55-eb02-499d-9775-2e0e25659e07  Company Moodle
# 977  company-moodle  c6b7fbd0-7390-4370-ab77-45027596b520  Company Moodle
# 978  company-moodle  9df844fd-eefe-4880-8341-936732174bb5  Company Moodle
# 979        ud-learn  d0d366b2-71cb-47ef-9257-fc2f05fd0c4d         Udacity
# 980        ud-learn  3f78e98d-bc1d-4317-b576-538103be2935         Udacity
# 981        ud-learn  a376b08b-4015-4972-929e-f6eb36c6396c         Udacity
# 982        ud-learn  e26f21e2-61a0-411e-b03b-e690592d3f49         Udacity
# 983        ud-learn  46b0b85a-71dd-4138-a1ae-929f8558d104         Udacity
# 984        ud-learn  ad6642cf-b651-429e-8112-f095f2e2ff7f         Udacity
# 985        ud-learn  d910609c-cab0-4bd3-a659-016ff78a0bdd         Udacity
# 986        ud-learn  19740874-3da6-4669-8e4d-0edb549ee49b         Udacity
# ...

# %%
df_courses.to_csv('../starter/Data/courses_fixed.csv', index=False)
